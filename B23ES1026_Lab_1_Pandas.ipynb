# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayu-infinite/Practice/blob/main/B23ES1026_Lab_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1
# ## Just making the first row entries to 0 and then just filling all the null values with exact upper numerical values in same column.

# %%
import pandas as pd
import math

# %%
df=pd.read_csv('MELBOURNE_HOUSE_PRICES_LESS.csv')
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.shape
# Out:
# (63023, 13)

# %%
nan_rows = df[df.isna().any(axis=1)]
table=pd.DataFrame(nan_rows)
table
# Out:
#                  Suburb                Address  Rooms Type  Price Method  \
# 8             Albanvale          1 Jackson Cct      6    h    NaN     PI
# 15       Altona Meadows           57 Tatman Dr      4    h    NaN     SN
# 24            Ashburton              1 Pitt St      4    h    NaN      S
# 29              Attwood     46 Threadneedle St      4    h    NaN     SN
# 38         Balwyn North            12 Agnes Av      3    h    NaN     SP
# ...                 ...                    ...    ...  ...    ...    ...
# 63001      Wyndham Vale          15 Yaltara Dr      3    h    NaN      S
# 63008        Yarraville  4/247 Williamstown Rd      3    t    NaN      S
# 63010           Burwood           29 Summit Rd      4    h    NaN     PN
# 63021        Thomastown         3/1 Travers St      3    u    NaN     PI
# 63022  Williams Landing            1 Diadem Wy      4    h    NaN     SP
#
#              SellerG        Date  Postcode             Regionname  \
# ...

# %%
df.iloc[0]=0
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0                     0                 0      0    0        0.0      0
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.fillna(method='ffill', inplace=True)
df #filling those null values with the exact above numerical values
# Out:
# <ipython-input-14-7202bd6a8582>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
#                  Suburb           Address  Rooms Type      Price Method  \
# 0                     0                 0      0    0        0.0      0
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# ...

# %% [markdown]
# # Task 2
# ## Just removing the rows which contain null values.

# %%
import pandas as pd

# %%
df=pd.read_csv('MELBOURNE_HOUSE_PRICES_LESS.csv')
df #just overlooking :
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
print(df.isna().sum())
# Please notice here below that The Price Column has 14590 NaN entries gonna remove those rows
# This was like key point for further analysis
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price            14590
# Method               0
# SellerG              0
# Date                 0
# Postcode             0
# Regionname           0
# Propertycount        0
# Distance             0
# CouncilArea          0
# dtype: int64

# %%
df_no_nan=df.dropna(inplace=True) # dropping those rows
df_no_nan = df.dropna() #stored it as another object
df_no_nan
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford     59A Turner St      3    h  1220000.0      S
# 2         Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4       Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...              ...               ...    ...  ...        ...    ...
# 63016      Frankston    4/34 Petrie St      2    u   347700.0     SP
# 63017        Preston     229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
#
#         SellerG        Date  Postcode                  Regionname  \
# 0        Jellis   1/04/2017      3067       Northern Metropolitan
# ...

# %%
# Here as seen above the rows got reduced which contained the NaN values.
print(df_no_nan.shape)
# Out:
# (48433, 13)

# %% [markdown]
# # Task 3
# ## Just filled the null value places by the mean of the values corresponding to the same column.

# %%
import pandas as pd
import math

# %%
df=pd.read_csv('MELBOURNE_HOUSE_PRICES_LESS.csv')
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.fillna(df.select_dtypes(include=[np.number]).mean(), inplace=True)
df
# Needed to select the datatype as numerical because other columns were not of numerical type except price column
# which contained null values
# Out:
#                  Suburb           Address  Rooms Type         Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1.490000e+06      S
# 1            Abbotsford     59A Turner St      3    h  1.220000e+06      S
# 2            Abbotsford     119B Yarra St      3    h  1.420000e+06      S
# 3            Aberfeldie        68 Vida St      3    h  1.515000e+06      S
# 4          Airport West  92 Clydesdale Rd      2    h  6.700000e+05      S
# ...                 ...               ...    ...  ...           ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h  5.660000e+05      S
# 63019     Roxburgh Park       9 Parker Ct      3    h  5.000000e+05      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h  5.450000e+05      S
# 63021        Thomastown    3/1 Travers St      3    u  9.978982e+05     PI
# 63022  Williams Landing       1 Diadem Wy      4    h  9.978982e+05     SP
#
# ...
